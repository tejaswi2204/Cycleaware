# %%
exec(open(r"C:\Users\User\Downloads\New Project\edge_case_tests.py", encoding="utf-8").read())
# Out:
# ...
#   CYCLEAWARE — EDGE CASE TEST RESULTS
# ...
#
# Group 1 — Extreme Personal Profiles
# ----------------------------------------------------------------------
#                                 Test Status Spotting % Spotting Predicted Gap (days) Pass
# Youngest user — Age 13, no condition     OK      33.1%                 No        N/A    —
# Oldest user — Age 45, PCOS, high BMI     OK      58.7%                Yes        N/A PASS
#        Severely underweight — BMI 14     OK      33.7%                 No        N/A    —
#                       Obese — BMI 40     OK      34.5%                 No        N/A    —
#   Endometriosis — high spotting risk     OK      44.7%                 No        N/A FAIL
#                    Thyroid condition     OK      41.2%                 No        N/A    —
#
# Group 2 — Extreme Stress and Lifestyle
# ----------------------------------------------------------------------
# ...

# %%
exec(open(r"C:\Users\User\Downloads\New Project\edge_case_tests_v2.py", encoding="utf-8").read())
# Out:
# ...
#   CYCLEAWARE — EDGE CASE TEST RESULTS v2
# ...
#
# Group 1 — Extreme Personal Profiles
# ---------------------------------------------------------------------------
#                                     Test Spotting % Predicted Gap Pass                                           Note
#                   Age 13 — youngest user      33.1%        No N/A    —           No expectation — observing behaviour
# Age 45, PCOS, BMI 38 — high risk profile      58.7%       Yes N/A PASS      High risk profile should predict spotting
#            BMI 14 — severely underweight      33.7%        No N/A    —               Observing — no clear expectation
#                           BMI 40 — obese      34.5%        No N/A    —               Observing — no clear expectation
#        Endometriosis with strong history      50.0%       Yes N/A PASS Strong history added — should predict spotting
# ...
